# %% [markdown]
# # Mask2Face
# This notebook will guide you through all the steps described in this article to build and train your ML model for removing the face mask of the person's face.

# %%
# Necessary imports
import os
import tarfile
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from utils import download_data
from utils.configuration import Configuration
from utils.data_generator import DataGenerator
from utils.architectures import UNet
from utils.model import Mask2FaceModel

# setup HW

# is GPU available
gpu_physical_devices = tf.config.experimental.list_physical_devices('GPU')
if len(gpu_physical_devices) > 0:
    tf.config.experimental.set_memory_growth(gpu_physical_devices[0], True)

# check HW availability
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print("Num CPUs Available: ", len(tf.config.experimental.list_physical_devices('CPU')))

# %% [markdown]
# ## 1) Preconditions
# First we need a dataset of human faces.

# %%
# Check if dataset is already downloaded or needs to be downloaded.
configuration = Configuration()
dataset_path = configuration.get('input_images_path')
if os.path.isdir(dataset_path):
    print('Dataset already downloaded')
else:
    print('Downloading dataset')
    dataset_archive_path = os.path.join('data', 'lfw-deepfunneled.tgz')
    download_data(configuration.get('dataset_archive_download_url'), dataset_archive_path)
    print('Extracting dataset')
    tar = tarfile.open(dataset_archive_path, 'r:gz')
    tar.extractall('data')
    tar.close()
    print('Done')
# Out:
# Dataset already downloaded

# %% [markdown]
# ## 2) Data generation
# Next step is to generate data for neural network training. We need input images (person with a face mask) and corresponding output image (the same image as input but without the face mask). We already have output images in downloaded dataset. Input images will be created by adding mask on the faces with a help from [MaskTheFace GitHub](https://github.com/aqeelanwar/MaskTheFace) project.

# %%
# setup the pipeline and generate data

dg = DataGenerator(configuration)

train_folder = configuration.get('train_data_path')
test_folder = configuration.get('test_data_path')

if os.path.exists(train_folder) and os.path.exists(test_folder):
    print('Testing and training data already generated')
else:
    dg.generate_images()

print('Here are few examples of generated data.')
n_examples = 5
inputs, outputs = dg.get_dataset_examples(n_examples)
f, axarr = plt.subplots(2, n_examples, figsize=(20, 10))
for i in range(len(inputs)):
    axarr[1, i].imshow(mpimg.imread(inputs[i]))
    axarr[1, i].axis('off')
    axarr[0, i].imshow(mpimg.imread(outputs[i]))
    axarr[0, i].axis('off')
# Out:
# Testing and training data already generated
# Here are few examples of generated data.

# %% [markdown]
# ## 3) Model training
# Now we have all the data, and we can initiate model and start training.

# %%
# Feel free to experiment with the number of filters, their sizes or any other parameters
filters = (64, 128, 128, 256, 256, 512)
kernels = (7, 7, 7, 3, 3, 3)
input_image_size = (256, 256, 3)
architecture = UNet.RESNET
training_epochs = 20
batch_size = 7

# %%
# Create instance of model and start training
model = Mask2FaceModel.build_model(architecture=architecture, input_size=input_image_size, filters=filters,
                                   kernels=kernels, configuration=configuration)
model.train(epochs=training_epochs, batch_size=batch_size, loss_function='ssim_l1_loss')

# If you already have pretrained model you can uncomment next line and load it instead of training new one
#model = Mask2FaceModel.load_model('path_to_your_trained_model.h5')
# Out:
# Using UNet Resnet model
# Loading training data from data/train with limit of 10000 images
# Loading testing data from data/test with limit of 1000 images
# 15/15 [==============================] - 31s 838ms/step - loss: 0.6959 - acc: 0.1452 - recall: 0.5245 - precision: 0.9821
# - TEST -> LOSS:     0.6959, ACC:     0.1452, RECALL:     0.5245, PRECISION:     0.9821
# Epoch 1/20
# 1143/1143 [==============================] - 3103s 3s/step - loss: 0.1710 - acc: 0.8481 - recall: 0.4541 - precision: 1.0000 - val_loss: 0.1293 - val_acc: 0.8877 - val_recall: 0.3949 - val_precision: 0.9996
# C:\Users\HyupsungPC\Anaconda3\envs\mask2face1\lib\site-packages\keras\utils\generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/20
# 1143/1143 [==============================] - 3052s 3s/step - loss: 0.0917 - acc: 0.9224 - recall: 0.4084 - precision: 1.0000 - val_loss: 0.0898 - val_acc: 0.9245 - val_recall: 0.4193 - val_precision: 1.0000
# Epoch 3/20
# 1143/1143 [==============================] - 3047s 3s/step - loss: 0.0772 - acc: 0.9188 - recall: 0.4040 - precision: 1.0000 - val_loss: 0.0800 - val_acc: 0.9169 - val_recall: 0.4099 - val_precision: 1.0000
# Epoch 4/20
# 1143/1143 [==============================] - 3049s 3s/step - loss: 0.0707 - acc: 0.9192 - recall: 0.4038 - precision: 1.0000 - val_loss: 0.0675 - val_acc: 0.9012 - val_recall: 0.3905 - val_precision: 1.0000
# Epoch 5/20
# 1143/1143 [==============================] - 3049s 3s/step - loss: 0.0682 - acc: 0.9159 - recall: 0.4039 - precision: 1.0000 - val_loss: 0.0709 - val_acc: 0.9052 - val_recall: 0.4455 - val_precision: 1.0000
# Epoch 6/20
# 1143/1143 [==============================] - 3048s 3s/step - loss: 0.0654 - acc: 0.9174 - recall: 0.4033 - precision: 1.0000 - val_loss: 0.0632 - val_acc: 0.9092 - val_recall: 0.4100 - val_precision: 1.0000
# Epoch 7/20
# 1143/1143 [==============================] - 3047s 3s/step - loss: 0.0628 - acc: 0.9224 - recall: 0.4021 - precision: 1.0000 - val_loss: 0.0741 - val_acc: 0.8938 - val_recall: 0.3798 - val_precision: 1.0000
# Epoch 8/20
# 1143/1143 [==============================] - 3048s 3s/step - loss: 0.0612 - acc: 0.9194 - recall: 0.4036 - precision: 1.0000 - val_loss: 0.0588 - val_acc: 0.9185 - val_recall: 0.4150 - val_precision: 1.0000
# Epoch 9/20
# 1143/1143 [==============================] - 3047s 3s/step - loss: 0.0593 - acc: 0.9203 - recall: 0.4033 - precision: 1.0000 - val_loss: 0.0639 - val_acc: 0.9099 - val_recall: 0.4210 - val_precision: 1.0000
# Epoch 10/20
# 1143/1143 [==============================] - 3046s 3s/step - loss: 0.0582 - acc: 0.9282 - recall: 0.4032 - precision: 1.0000 - val_loss: 0.0600 - val_acc: 0.9373 - val_recall: 0.3892 - val_precision: 1.0000
# Epoch 11/20
# 1143/1143 [==============================] - 3045s 3s/step - loss: 0.0560 - acc: 0.9290 - recall: 0.4024 - precision: 1.0000 - val_loss: 0.0576 - val_acc: 0.9178 - val_recall: 0.4266 - val_precision: 1.0000
# Epoch 12/20
# 1143/1143 [==============================] - 3046s 3s/step - loss: 0.0557 - acc: 0.9254 - recall: 0.4043 - precision: 1.0000 - val_loss: 0.0588 - val_acc: 0.9372 - val_recall: 0.4175 - val_precision: 1.0000
# Epoch 13/20
# 1143/1143 [==============================] - 3046s 3s/step - loss: 0.0543 - acc: 0.9316 - recall: 0.4027 - precision: 1.0000 - val_loss: 0.0584 - val_acc: 0.8850 - val_recall: 0.4131 - val_precision: 1.0000
# Epoch 14/20
# 1143/1143 [==============================] - 3046s 3s/step - loss: 0.0535 - acc: 0.9337 - recall: 0.4034 - precision: 1.0000 - val_loss: 0.0593 - val_acc: 0.9267 - val_recall: 0.4110 - val_precision: 1.0000
# Epoch 15/20
# 1143/1143 [==============================] - 3046s 3s/step - loss: 0.0531 - acc: 0.9279 - recall: 0.4019 - precision: 1.0000 - val_loss: 0.0582 - val_acc: 0.9319 - val_recall: 0.4010 - val_precision: 1.0000
# Epoch 16/20
# 1143/1143 [==============================] - 3045s 3s/step - loss: 0.0519 - acc: 0.9357 - recall: 0.4024 - precision: 1.0000 - val_loss: 0.0543 - val_acc: 0.9265 - val_recall: 0.4243 - val_precision: 1.0000
# Epoch 17/20
# 1143/1143 [==============================] - 3045s 3s/step - loss: 0.0511 - acc: 0.9318 - recall: 0.4035 - precision: 1.0000 - val_loss: 0.0566 - val_acc: 0.9260 - val_recall: 0.4288 - val_precision: 1.0000
# Epoch 18/20
# 1143/1143 [==============================] - 3044s 3s/step - loss: 0.0502 - acc: 0.9308 - recall: 0.4030 - precision: 1.0000 - val_loss: 0.0530 - val_acc: 0.9164 - val_recall: 0.4073 - val_precision: 1.0000
# Epoch 19/20
# 1143/1143 [==============================] - 3046s 3s/step - loss: 0.0500 - acc: 0.9326 - recall: 0.4027 - precision: 1.0000 - val_loss: 0.0507 - val_acc: 0.9355 - val_recall: 0.3965 - val_precision: 1.0000
# Epoch 20/20
# 1143/1143 [==============================] - 3046s 3s/step - loss: 0.0497 - acc: 0.9336 - recall: 0.4036 - precision: 1.0000 - val_loss: 0.0545 - val_acc: 0.9147 - val_recall: 0.4094 - val_precision: 1.0000
# 15/15 [==============================] - 9s 612ms/step - loss: 0.0572 - acc: 0.9226 - recall: 0.4339 - precision: 1.0000
# - TEST -> LOSS:     0.0572, ACC:     0.9226, RECALL:     0.4339, PRECISION:     1.0000

# %% [markdown]
# ## 4) Results
# Our model is trained, and we can look at it's performance

# %%
# Let's see the results on a random testing image unseen by the model before.
# Run this cell multiple times to see different results
n_examples = 3
input_imgs, true_output_imgs = dg.get_dataset_examples(n_examples, test_dataset=False)
f, axarr = plt.subplots(n_examples, 3, figsize=(10, n_examples * 3))
for i, img in enumerate(input_imgs):
    generated_output = model.predict(img)
    axarr[i, 0].imshow(mpimg.imread(input_imgs[i]))
    axarr[i, 0].axis('off')
    axarr[i, 1].imshow(mpimg.imread(true_output_imgs[i]))
    axarr[i, 1].axis('off')
    axarr[i, 2].imshow(generated_output)
    axarr[i, 2].axis('off')

axarr[0, 0].set_title('Input images')
axarr[0, 1].set_title('Real outputs')
axarr[0, 2].set_title('Generated outputs')
print('Outputs generated on previously unseen data.')
# Out:
# (256, 256)
# (256, 256)
# (255, 256)
# Outputs generated on previously unseen data.

# %% [markdown]
# 5) Results 2

# %%
# Let's see the results on a random testing image unseen by the model before.
# Run this cell multiple times to see different results
n_examples = 3
input_imgs, true_output_imgs = dg.get_dataset_examples(n_examples, test_dataset=True)
f, axarr = plt.subplots(n_examples, 3, figsize=(10, n_examples * 3))
for i, img in enumerate(input_imgs):
    generated_output = model.predict(img)
    axarr[i, 0].imshow(mpimg.imread(input_imgs[i]))
    axarr[i, 0].axis('off')
    axarr[i, 1].imshow(mpimg.imread(true_output_imgs[i]))
    axarr[i, 1].axis('off')
    axarr[i, 2].imshow(generated_output)
    axarr[i, 2].axis('off')

axarr[0, 0].set_title('Input images')
axarr[0, 1].set_title('Real outputs')
axarr[0, 2].set_title('Generated outputs')
print('Outputs generated on previously unseen data.')
# Out:
# (236, 246)
# (250, 256)
# (256, 256)
# (244, 256)
# (256, 256)
# (245, 256)
# (235, 256)
# (244, 256)
# (245, 256)
# (179, 216)
# Outputs generated on previously unseen data.
